# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# plot

year = [1950,1970,1990,2010,2020]
pop = [2.5,3.6,5.2,6.9,7.5]

plt.plot(year, pop) # x axis = year; y axis = pop 
plt.grid(alpha=0.2)
plt.show()

# %%
# Scatter plot

year = [1950,1970,1990,2010,2020]
pop = [2.5,3.6,5.2,6.9,7.5]

plt.scatter(year, pop) # x = year; y = pop
plt.grid(alpha=0.3)
plt.show()

# %%
# Import data gapminder.csv

DATA_PATH = '/home/gustavo/Documents/Study/005_Python_General/github/python_practice/09_libraries/00_data/gapminder.csv'

gdp_data_2007 = pd.read_csv(DATA_PATH)

gdp_data_2007.head(3)
# Out:
#    Unnamed: 0      country  year  population    cont  life_exp      gdp_cap
# 0          11  Afghanistan  2007  31889923.0    Asia    43.828   974.580338
# 1          23      Albania  2007   3600523.0  Europe    76.423  5937.029526
# 2          35      Algeria  2007  33333216.0  Africa    72.301  6223.367465

# %% [markdown]
# ## Exploring correlations

# %%
plt.scatter(gdp_data_2007['gdp_cap'], gdp_data_2007['life_exp']) # Passing the data
plt.xscale('log') # Show data in logarithmic scale
plt.xlabel("GDP cap")
plt.ylabel("Life expectancy")
plt.grid(alpha=0.2)
plt.show()

# %%
plt.scatter(gdp_data_2007['population'], gdp_data_2007['life_exp'])
plt.ylabel("Life Expectancy")
plt.xlabel("Population")
plt.show()
