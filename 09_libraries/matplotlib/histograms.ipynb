# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
help(plt.hist)
# Out:
# Help on function hist in module matplotlib.pyplot:
#
# hist(x: 'ArrayLike | Sequence[ArrayLike]', bins: 'int | Sequence[float] | str | None' = None, *, range: 'tuple[float, float] | None' = None, density: 'bool' = False, weights: 'ArrayLike | None' = None, cumulative: 'bool | float' = False, bottom: 'ArrayLike | float | None' = None, histtype: "Literal['bar', 'barstacked', 'step', 'stepfilled']" = 'bar', align: "Literal['left', 'mid', 'right']" = 'mid', orientation: "Literal['vertical', 'horizontal']" = 'vertical', rwidth: 'float | None' = None, log: 'bool' = False, color: 'ColorType | Sequence[ColorType] | None' = None, label: 'str | Sequence[str] | None' = None, stacked: 'bool' = False, data=None, **kwargs) -> 'tuple[np.ndarray | list[np.ndarray], np.ndarray, BarContainer | Polygon | list[BarContainer | Polygon]]'
#     Compute and plot a histogram.
#
#     This method uses `numpy.histogram` to bin the data in *x* and count the
# ...

# %%
values = [0,0.6,1.4,1.6,2.2,2.5,2.6,3.2,3.5,3.9,4.2,6]
plt.hist(values, bins=3) # values divided in 3 bins
plt.show()

# %%
PATH_DATA = '/home/gustavo/Documents/Study/005_Python_General/github/python_practice/09_libraries/00_data/gapminder.csv'

gdp_data = pd.read_csv(PATH_DATA)

gdp_data8
# Out:
#      Unnamed: 0             country  year  population      cont  life_exp  \
# 0            11         Afghanistan  2007  31889923.0      Asia    43.828
# 1            23             Albania  2007   3600523.0    Europe    76.423
# 2            35             Algeria  2007  33333216.0    Africa    72.301
# 3            47              Angola  2007  12420476.0    Africa    42.731
# 4            59           Argentina  2007  40301927.0  Americas    75.320
# ..          ...                 ...   ...         ...       ...       ...
# 137        1655             Vietnam  2007  85262356.0      Asia    74.249
# 138        1667  West Bank and Gaza  2007   4018332.0      Asia    73.422
# 139        1679         Yemen, Rep.  2007  22211743.0      Asia    62.698
# 140        1691              Zambia  2007  11746035.0    Africa    42.384
# 141        1703            Zimbabwe  2007  12311143.0    Africa    43.487
#
#           gdp_cap
# 0      974.580338
# 1     5937.029526
# 2     6223.367465
# ...

# %%
dict_colors = {
    'Asia':'red',
    'Europe':'green',
    'Africa':'blue',
    'Americas':'yellow',
    'Oceania':'black'
}



plt.scatter(gdp_data['gdp_cap'], gdp_data['life_exp'], s=gdp_data['population']/1000000, alpha=0.8)

plt.xscale('log')
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')

tick_val = [1000, 10000, 100000] # values for ticks
tick_lab = ['1k', '10k', '100k'] # values for labels

plt.xticks(tick_val, tick_lab)

plt.grid(alpha=0.3)

plt.show()
