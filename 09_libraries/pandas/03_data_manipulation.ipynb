# %%
import pandas as pd
import numpy as np

# %%
DATA_PATH = '/home/gustavo/repos/Python_practice/09_libraries/00_data/netflix_data.csv'
DATA_PATH_2 = '/home/gustavo/Documents/Study/005_Python_General/github/python_practice/09_libraries/00_data/netflix_data.csv'

df = pd.read_csv(DATA_PATH_2, delimiter=',', index_col=0)
df.head(3)
# Out:
#           type  title           director  \
# show_id
# s2       Movie   7:19  Jorge Michel Grau
# s3       Movie  23:59       Gilbert Chan
# s4       Movie      9        Shane Acker
#
#                                                       cast        country  \
# show_id
# s2       Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# s3       Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# s4       Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
#
#                 date_added  release_year  duration  \
# show_id
# s2       December 23, 2016          2016        93
# s3       December 20, 2018          2011        78
# s4       November 16, 2017          2009        80
#
#                                                description          genre
# show_id
# s2       After a devastating earthquake hits Mexico Cit...         Dramas
# s3       When an army recruit is found dead, his fellow...  Horror Movies
# ...

# %%
# Parts of a DataFrame

# df.values
# df.index
# df.columns

df.columns
# Out:
# Index(['type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'duration', 'description', 'genre'],
#       dtype='object')

# %% [markdown]
# ## Sorting values

# %%
# df.sort_values('column') >>> ascending order
# df.sort_values('column', ascending=False) >>>> descending order
# df.sort_values(['column_1', 'column_2'])

# %%
df.sort_values('country').head(3)
# Out:
#           type                      title                     director  \
# show_id
# s4747    Movie          Palermo Hollywood                Eduardo Pinto
# s6307    Movie  The Distinguished Citizen  Gastón Duprat, Mariano Cohn
# s7344    Movie                  Underdogs         Juan José Campanella
#
#                                                       cast    country  \
# show_id
# s4747    Brian Maya, Matías Desiderio, Manuela Pal, Azu...  Argentina
# s6307    Oscar Martínez, Dady Brieva, Andrea Frigerio, ...  Argentina
# s7344    Ariana Grande, Nicholas Hoult, Matthew Morriso...  Argentina
#
#                 date_added  release_year  duration  \
# show_id
# s4747      October 8, 2020          2004       106
# s6307    September 1, 2017          2016       113
# s7344        June 15, 2020          2013        85
#
#                                                description     genre
# show_id
# s4747    A pair of petty criminals from different backg...    Dramas
# ...

# %%
df.sort_values('duration', ascending=True).head(5)
# Out:
#             type                             title  \
# show_id
# s3099    TV Show                       Jack Taylor
# s3852    TV Show  Maggie & Bianca: Fashion Friends
# s3003    TV Show                 Inhuman Resources
# s4725    TV Show                   Paava Kadhaigal
# s4701    TV Show       Ouran High School Host Club
#
#                                                   director  \
# show_id
# s3099                                          Stuart Orme
# s3852                                       Iginio Straffi
# s3003                                         Ziad Doueiri
# s4725    Sudha Kongara, Vignesh Shivan, Gautham Vasudev...
# s4701                                      Takuya Igarashi
#
#                                                       cast        country  \
# show_id
# s3099    Iain Glen, Killian Scott, Nora-Jane Noone, Tar...  United States
# s3852    Emanuela Rei, Giorgia Boni, Sergio Ruggeri, Lu...          Italy
# ...

# %%
# Sorting by two columns

df.sort_values(['country', 'release_year', 'duration'], ascending=[True, True, False]).head(10)
# Out:
#           type                      title  \
# show_id
# s2029    Movie       Esperando La Carroza
# s4871    Movie         Pizza, birra, faso
# s4747    Movie          Palermo Hollywood
# s1376    Movie     Chronicle of an Escape
# s6071    Movie                 The Aerial
# s7344    Movie                  Underdogs
# s1581    Movie                  Daemonium
# s3826    Movie                     Lusers
# s292     Movie                   Abzurdah
# s6307    Movie  The Distinguished Citizen
#
#                                       director  \
# show_id
# s2029                          Alejandro Doria
# s4871    Israel Adrián Caetano, Bruno Stagnaro
# s4747                            Eduardo Pinto
# s1376                    Israel Adrián Caetano
# s6071                            Esteban Sapir
# s7344                     Juan José Campanella
# s1581                              Pablo Parés
# s3826                          Ticoy Rodriguez
# ...

# %% [markdown]
# ## Subsetting rows

# %%
condition_1 = df['duration'] > 210

df[condition_1]
# Out:
#           type                   title                director  \
# show_id
# s3196    Movie            Jodhaa Akbar      Ashutosh Gowariker
# s3522    Movie                  Lagaan      Ashutosh Gowariker
# s4491    Movie          No Longer kids         Samir Al Asfory
# s5377    Movie                  Sangam              Raj Kapoor
# s6851    Movie  The School of Mischief  Houssam El-Din Mustafa
#
#                                                       cast country  \
# show_id
# s3196    Hrithik Roshan, Aishwarya Rai Bachchan, Sonu S...   India
# s3522    Aamir Khan, Gracy Singh, Rachel Shelley, Paul ...   India
# s4491    Said Saleh, Hassan Moustafa, Ahmed Zaki, Youne...   Egypt
# s5377    Raj Kapoor, Vyjayanthimala, Rajendra Kumar, La...   India
# s6851    Suhair El-Babili, Adel Emam, Saeed Saleh, Youn...   Egypt
#
#                 date_added  release_year  duration  \
# show_id
# s3196      October 1, 2018          2008       214
# ...

# %%
condition_2 = df['release_year'] == 1991

df[condition_2]
# Out:
#           type                                              title  \
# show_id
# s487     Movie                 An American Tail: Fievel Goes West
# s920     Movie                        Bill Hicks: One Night Stand
# s1629    Movie                              Daughters of the Dust
# s2800    Movie                                               Hook
# s4321    Movie                                            My Girl
# s4702    Movie                                        Out of Life
# s5359    Movie             Sam Kinison: Family Entertainment Hour
# s5360    Movie                         Sam Kinison: Live in Vegas
# s5565    Movie                                            Shikari
# s5698    Movie                                 Solo Con Tu Pareja
# s6015    Movie  Teenage Mutant Ninja Turtles II: The Secret of...
# s6553    Movie                                 The Last Boy Scout
# s7231    Movie                               Triumph of the Heart
# ...

# %%
condition_3 = df['country'] == 'Colombia'

df[condition_3].sort_values('release_year', ascending=False)
# Out:
#             type                                       title  \
# show_id
# s498       Movie                   An Unremarkable Christmas
# s1671      Movie                              Death Can Wait
# s1029    TV Show                                     Bolívar
# s1965      Movie                   El sendero de la anaconda
# s3796      Movie                            Loving is Losing
# s569       Movie              Arango y Sanint: Ríase el show
# s1967      Movie                                  El testigo
# s2148      Movie                            Feo pero sabroso
# s4819      Movie                                Penalty Kick
# s5596      Movie  Si saben cómo me pongo ¿pá qué me invitan?
# s5198      Movie              Ricardo Quevedo: Hay gente así
# s4854      Movie                                 Pickpockets
# s3507    TV Show                              La Viuda Negra
#
#                                                   director  \
# show_id
# ...

# %%
condition_4 = df['country'] == 'Brazil'
condition_5 = df['release_year'] > 2018

df[condition_4 & condition_5]
# Out:
#             type                                    title  \
# show_id
# s219     TV Show                          A Queen Is Born
# s321       Movie                Afonso Padilha: Classless
# s395       Movie                             Alice Junior
# s532     TV Show                  Anitta: Made In Honório
# s1787      Movie                            DJ Cinderella
# s1833      Movie                               Double Dad
# s3248      Movie                   Just Another Christmas
# s3307      Movie                                   Kardec
# s3653      Movie        Liss Pereira: Reteniendo líquidos
# s3801      Movie  Luccas Neto em: Acampamento de Férias 2
# s3803      Movie              Luccas Neto in: Summer Camp
# s3804      Movie     Luccas Neto in: The End of Christmas
# s3994      Movie     Maurício Meirelles: Generating Chaos
# s4520      Movie                        Nothing to Lose 2
# s5200      Movie                             Rich in Love
# ...

# %%
df.columns
# Out:
# Index(['type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'duration', 'description', 'genre'],
#       dtype='object')

# %%
condition_6 = df['genre'].isin(['Action', 'Comedies'])

df[condition_6]
# Out:
#           type                     title                 director  \
# show_id
# s4       Movie                         9              Shane Acker
# s19      Movie                    15-Aug       Swapnaneel Jayakar
# s22      Movie              ​Goli Soda 2             Vijay Milton
# s34      Movie              #realityhigh         Fernando Lebrija
# s35      Movie                     #Roxy          Michael Kennedy
# ...        ...                       ...                      ...
# s7761    Movie                 Zaki Chan               Wael Ihsan
# s7763    Movie                  Zed Plus  Chandra Prakash Dwivedi
# s7765    Movie                      Zero               Aanand Rai
# s7770    Movie  Zindagi Na Milegi Dobara              Zoya Akhtar
# s7779    Movie                Zombieland          Ruben Fleischer
#
#                                                       cast        country  \
# show_id
# s4       Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# ...

# %% [markdown]
# ## Adding columns

# %%
# Convert duration in minutes to hours

df['duration_hours'] = df['duration'] / 60
df.head(5)
# Out:
#             type  title           director  \
# show_id
# s2         Movie   7:19  Jorge Michel Grau
# s3         Movie  23:59       Gilbert Chan
# s4         Movie      9        Shane Acker
# s5         Movie     21     Robert Luketic
# s6       TV Show     46        Serdar Akar
#
#                                                       cast        country  \
# show_id
# s2       Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# s3       Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# s4       Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# s5       Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# s6       Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
#
#                 date_added  release_year  duration  \
# show_id
# s2       December 23, 2016          2016        93
# s3       December 20, 2018          2011        78
# s4       November 16, 2017          2009        80
# ...
