# %%
import pandas as pd
import numpy as np

# %%
PATH_DATA_1 = '/home/gustavo/repos/Python_practice/09_libraries/00_data/netflix_data.csv'
PATH_DATA_2 = '/home/gustavo/Documents/Study/005_Python_General/github/python_practice/09_libraries/00_data/netflix_data.csv'

# %%
df = pd.read_csv(PATH_DATA_2, delimiter=',', index_col=0)
df.head(3)
# Out:
#           type  title           director  \
# show_id
# s2       Movie   7:19  Jorge Michel Grau
# s3       Movie  23:59       Gilbert Chan
# s4       Movie      9        Shane Acker
#
#                                                       cast        country  \
# show_id
# s2       Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# s3       Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# s4       Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
#
#                 date_added  release_year  duration  \
# show_id
# s2       December 23, 2016          2016        93
# s3       December 20, 2018          2011        78
# s4       November 16, 2017          2009        80
#
#                                                description          genre
# show_id
# s2       After a devastating earthquake hits Mexico Cit...         Dramas
# s3       When an army recruit is found dead, his fellow...  Horror Movies
# ...

# %% [markdown]
# ## Data exploration

# %%
df.columns
# Out:
# Index(['type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'duration', 'description', 'genre'],
#       dtype='object')

# %% [markdown]
# ## Summaries by group

# %%
df.groupby('genre')['duration'].sum()
# Out:
# genre
# Action                   78758
# Anime Features            1732
# Anime Series                24
# British TV                  51
# Children                 35046
# Classic                     15
# Classic Movies            8172
# Comedies                110293
# Crime TV                    51
# Cult Movies               1140
# Documentaries            29910
# Docuseries                   8
# Dramas                  150143
# Horror Movies            23191
# Independent Movies        1974
# International Movies     11224
# International TV            55
# Kids                        15
# LGBTQ Movies                99
# Music                     1267
# Reality TV                   2
# Romantic Movies            250
# Romantic TV                  1
# Sci-Fi                    1189
# Stand-Up                 18383
# TV Action                   10
# TV Comedies                 11
# TV Horror                    3
# TV Shows                     4
# Thrillers                 4765
# ...
